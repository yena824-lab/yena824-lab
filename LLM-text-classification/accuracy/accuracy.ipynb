# %%
import pandas as pd

# %% [markdown]
# llama3-3b fine-tuning (zero shot)

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/0824_trained_llama3-3b_zero_valdata.csv")
pred_csv
# Out:
#                                                   제목+내용        대분류    중분류  \
# 0     세계동물보건기구, 고병원성 조류 인플루엔자 동물 감염 현황(11.30) 1. 아일랜...  생물학적 위해요소  동식물질병
# 1     세계동물보건기구, 고병원성 조류 인플루엔자 동물 감염 현황(1.11) 1. 일본, ...  생물학적 위해요소  동식물질병
# 2     CODEX, 제1차 향신료 및 요리용 허브 분과위원회 회의 보고서 발표 국제식품규격...         기타     기타
# 3     영국 공중보건국(PHE) 전문가들, 보건기관과 알코올 업계의  제휴 비판  영국 공...       영양건강     건강
# 4     뉴질랜드 일차산업부, 말버러 해협 지역 패류 생물독소 경고 발령 뉴질랜드 일차산업부...  생물학적 위해요소   생물독소
# ...                                                 ...        ...    ...
# 2532  세계동물보건기구, 고병원성 조류 인플루엔자 동물 감염 현황(2.14) 1. 몰도바,...  생물학적 위해요소  동식물질병
# 2533  미국 FDA, 2018년 12월 수입부적합(12) -제조사식별번호: 30107801...       표시광고     기타
# 2534  [회수]캐나다 Olympic Wholesale Co. Ltd., 알레르기 유발물질 ...       표시광고   알레르기
# 2535  유럽의회, EU집행위 '동물복제 및 관련 식품ㆍ사료 수입 금지' 법안 지지 유럽의회...    신규 위해요소   복제동물
# 2536  캐나다 농업농식품부장관, 유기농 부문 강화와 성장을 위해 8백만달러 원조 발표 유기...       안전위생     기타
#
#      예측 소분류
# 0      동물질병
# 1      동물질병
# 2        기타
# 3        보건
# ...

# %%
target_csv = pd.read_csv("/home/yena/Classification_module/val_data.csv")
target_csv
# Out:
#        국가명        수집일자                                                사이트  \
# 0     국제기구  2021-12-01        https://wahis.oie.int/#/events?viewAll=true
# 1     국제기구  2023-01-12          https://wahis.woah.org/#/event-management
# 2     국제기구  2014-02-21  http://www.codexalimentarius.org/meetings-repo...
# 3       영국  2018-09-14         https://www.bbc.co.uk/news/health-45502974
# 4     뉴질랜드  2019-03-02  https://www.mpi.govt.nz/news-and-resources/med...
# ...    ...         ...                                                ...
# 2532  국제기구  2022-02-15        https://wahis.oie.int/#/events?viewAll=true
# 2533    미국  2019-01-09  http://www.accessdata.fda.gov/scripts/importre...
# 2534   캐나다  2019-12-22  https://healthycanadians.gc.ca/recall-alert-ra...
# 2535  유럽연합  2015-06-18  http://www.europarl.europa.eu/news/en/news-roo...
# 2536   캐나다  2018-08-26  https://www.canada.ca/en/agriculture-agri-food...
#
#                                                      제목  \
# ...

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# llama3-3b fine-tuning (few shot)

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/llama3-3b_zero_valdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/val_data.csv")

# %%
pred_csv
# Out:
#                                                   제목+내용        대분류       중분류  \
# 0     캐나다, 미승인 운동보충 및 체중감량제 주의 안내 캐나다 보건부는 미승인 운동보충 ...   화학적 위해요소     의약품성분
# 1     세계동물보건기구, 고병원성 조류 인플루엔자 동물 감염 현황(4.19) 1. 미국, ...  생물학적 위해요소     동식물질병
# 2     미국 FDA, 2018년 8월 수입부적합(12)  -제조사식별번호: 30108522...       표시광고       제품명
# 3     미국 FDA, 5월 식품수입부적합 목록(13)  -제조사식별번호: 301125320...       표시광고  원료·성분·함량
# 4     영국, 환자들 '부드러운 병원식' 먹고 질식 국가보건서비스 관리기구(NHS Impr...       안전위생        안전
# ...                                                 ...        ...       ...
# 2529  [E/R]미국 Chuckanut Bay Foods LLC, 알레르기 유발성분 호두 ...       표시광고      알레르기
# 2530  캐나다 식품검사청, 브리티시컬럼비아 소 결핵 조사 최신 상황 업데이트 (3.11) ...  생물학적 위해요소     동식물질병
# 2531  캐나다 보건부, 비가열 곡물가루 안전 취급법 소개 캐나다 보건부는 생지, 묽은 반죽...       안전위생        안전
# 2532  [E/R]미국 SARA LEE FROZEN FOODS, 미표시된 알레르기 유발성분 ...       표시광고      알레르기
# 2533  캐나다 공중보건청, 냉동 닭고기 튀김 제품 관련 살모넬라 집단 감염 조사 현황(10...  생물학적 위해요소       미생물
#
#           예측 소분류
# 0            보건제
# ...

# %%
target_csv
# Out:
#        국가명        수집일자                                                사이트  \
# 0      캐나다  2017-02-11  http://healthycanadians.gc.ca/recall-alert-rap...
# 1     국제기구         NaN          https://wahis.woah.org/#/event-management
# 2       미국  2018-09-06  http://www.accessdata.fda.gov/scripts/importre...
# 3       미국  2016-06-08  http://www.accessdata.fda.gov/scripts/importre...
# 4       영국  2018-06-28           https://www.bbc.com/news/health-44628779
# ...    ...         ...                                                ...
# 2530    미국  2020-07-29  https://www.accessdata.fda.gov/scripts/ires/in...
# 2531   캐나다  2019-03-12  http://inspection.gc.ca/animals/terrestrial-an...
# 2532   캐나다  2017-06-28  http://healthycanadians.gc.ca/recall-alert-rap...
# 2533    미국  2021-06-02  https://www.accessdata.fda.gov/scripts/ires/in...
# 2534   캐나다  2017-11-02  https://www.canada.ca/en/public-health/service...
#
#                                                      제목  \
# ...

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
train = pd.read_csv("/home/yena/Classification_module/train_data.csv")
print(len(train))
# Out:
# 20291

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/llama3-3b_zero_testdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/test_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# llama3-3b few shot

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/llama3-3b_few shot_valdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/val_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/llama3-3b_few shot_testdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/test_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# llama3 3b fine-tuning zero

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/trained_llama3-3b_zero_testdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/test_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
import pandas as pd

# %%
pred1 = pd.read_csv("/home/yena/Classification_module/test_data.csv")
pred1
# Out:
#        국가명        수집일자                                                사이트  \
# 0      캐나다  2017-02-11  http://healthycanadians.gc.ca/recall-alert-rap...
# 1     국제기구         NaN          https://wahis.woah.org/#/event-management
# 2       미국  2018-09-06  http://www.accessdata.fda.gov/scripts/importre...
# 3       미국  2016-06-08  http://www.accessdata.fda.gov/scripts/importre...
# 4       영국  2018-06-28           https://www.bbc.com/news/health-44628779
# ...    ...         ...                                                ...
# 2530    미국  2020-07-29  https://www.accessdata.fda.gov/scripts/ires/in...
# 2531   캐나다  2019-03-12  http://inspection.gc.ca/animals/terrestrial-an...
# 2532   캐나다  2017-06-28  http://healthycanadians.gc.ca/recall-alert-rap...
# 2533    미국  2021-06-02  https://www.accessdata.fda.gov/scripts/ires/in...
# 2534   캐나다  2017-11-02  https://www.canada.ca/en/public-health/service...
#
#                                                      제목  \
# ...

# %%
pred2 = pd.read_csv("/home/yena/Classification_module/trained_llama3-3b_few_testdata.csv", engine='python')
pred2
# Out:
#                                                   제목+내용        대분류       중분류  \
# 0     캐나다, 미승인 운동보충 및 체중감량제 주의 안내 캐나다 보건부는 미승인 운동보충 ...   화학적 위해요소     의약품성분
# 1     세계동물보건기구, 고병원성 조류 인플루엔자 동물 감염 현황(4.19) 1. 미국, ...  생물학적 위해요소     동식물질병
# 2     미국 FDA, 2018년 8월 수입부적합(12)  -제조사식별번호: 30108522...       표시광고       제품명
# 3     미국 FDA, 5월 식품수입부적합 목록(13)  -제조사식별번호: 301125320...       표시광고  원료·성분·함량
# 4     영국, 환자들 '부드러운 병원식' 먹고 질식 국가보건서비스 관리기구(NHS Impr...       안전위생        안전
# ...                                                 ...        ...       ...
# 1227  [회수]뉴질랜드 Sulkem Company Ltd, 알레르기 유발 물질 땅콩 미표시...       표시광고      알레르기
# 1228  [회수]뉴질랜드 Pak'nSave Hornby, 유리/플라스틱 이물 혼입 가능성으로...   물리적 위해요소       이물질
# 1229  스페인 , 중국산 치자추출물을 사프란으로 위조 판매한 사기 집단 적발 스페인 치안경...       안전위생        위생
# 1230  [회수]캐나다 Pattison Food Group, 곤충 존재로 보리 가공품 회수 ...   물리적 위해요소       이물질
# 1231  [E/R]미국 Ukrop's Homestyle Foods, LLC, 이물(플라스틱)...   물리적 위해요소       이물질
#
#         예측 소분류
# 0       호모실데나필
# ...

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/trained_llama3-3b_zero_valdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/val_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# llama3 3b few-shot finetuning

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/trained_llama3-3b_few_testdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/test_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
pred_csv = pd.read_csv("/home/yena/Classification_module/trained_llama3-3b_few_valdata.csv", engine='python')
target_csv = pd.read_csv("/home/yena/Classification_module/val_data.csv")

# %%
from sklearn.metrics import classification_report
import pandas as pd

# 정답과 예측값
y_true = target_csv['소분류'].fillna('None').astype(str)
y_pred = pred_csv['예측 소분류'].fillna('None').astype(str)

# classification_report 생성
report_dict = classification_report(y_true, y_pred, output_dict=True)

# 딕셔너리를 DataFrame으로 변환
report_df = pd.DataFrame(report_dict).transpose()

# 소수점 자릿수 정리
report_df = report_df.round(3)

# 보기 좋게 출력
from IPython.display import display
display(report_df)
# Out:
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/yena/miniconda3/envs/yena/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
